# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import  pandas as pd

# %%
#installing an openpyxl 
df=pd.read_excel("C:\\Users\\TECHSKILLS 360\\Downloads\\Ujuzi Data Summary.xlsx")

# %%
pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
pip show openpyxl
# Out:
# Name: openpyxl
# Version: 3.1.5
# Summary: A Python library to read/write Excel 2010 xlsx/xlsm files
# Home-page: https://openpyxl.readthedocs.io
# Author: See AUTHORS
# Author-email: charlie.clark@clark-consulting.eu
# License: MIT
# Location: c:\Users\TECHSKILLS 360\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: et-xmlfile
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

#reading a xlms file
df=pd.read_excel("C:\\Users\\TECHSKILLS 360\\Downloads\\Ujuzi Data Summary.xlsx")

#reading the first few rows of the data
print(df.head())
# Out:
#   Student Registration Number               Timestamp    Sales Rep Name  \
# 0                     22-1039 2022-10-24 13:51:26.503     Patience Sosi
# 1                     22-1101 2022-11-29 17:00:05.988      Joan Cherono
# 2                      23-101 2022-12-01 15:53:15.000     Patience Sosi
# 3                      23-102 2022-12-02 10:22:44.975  Christine Kiarie
# 4                      23-103 2022-12-02 15:09:55.538     Patience Sosi
#
#   Student's First Name Students Middle Name Student's Last Name  \
# 0           Clementine                Nduku               Musau
# 1               Gladys                  NaN              Cherop
# 2              Belinda               Akinyi               Abuom
# 3            Hempstone               Evance              Odongo
# 4               Sandra              Wanjiru             Muthoni
#
#   Students ID Number Students ID Number Remarks  Student Telephone Contact  \
# ...

# %%
import pandas as pd

#reading a xlms file
df=pd.read_excel("C:\\Users\\TECHSKILLS 360\\Downloads\\Ujuzi Data Summary.xlsx")

#read a specific file from the xlms file
sheet_name="Admission Data"
df=pd.read_excel("C:\\Users\\TECHSKILLS 360\\Downloads\\Ujuzi Data Summary.xlsx","Admission Data",engine='openpyxl')

#display the first few rows of the data frame
print(df.head())
# Out:
#            Timestamp 2023 First_name Middle_name Last_name   Reg_no  \
# 0 2024-09-04 22:47:06.877    Jacinta       Mueni   Mutunga  24-1425
# 1 2024-09-04 22:44:21.760  Josephine    Adhiambo    Ongere  24-0000
# 2 2024-09-04 20:41:18.774     Sylvia      Wangui    Mwangi  24-1443
# 3 2024-09-04 20:23:35.466  Christine       Vuhya     Osore  24-1462
# 4 2024-09-04 16:14:21.477     Mereen      Mwende   Ndigwa   24-1468
#
#    Id_number    Id_remark      Tel_no Alt_tel_no              E-mail_address  \
# 0   40429779  National ID  0113828587        NaN  mutungajacinta34@gmail.com
# 1    2427781  National ID  0714681505        NaN        mjadhiambo@gmail.com
# 2  261560505  National ID  0711831388        NaN    mwangisylvia56@gmail.com
# 3   24763512  National ID  0718023204        NaN        tintin8462@gmail.com
# 4   42168235  National ID  0790910531        NaN      mereenmwende@gmail.com
#
#    ...                  Languages Combo                  Full Name  \
# ...

# %%
import pandas as pd

#reading a xlms file
df=pd.read_excel("C:\\Users\\TECHSKILLS 360\\Downloads\\Ujuzi Data Summary.xlsx")

#read a specific file from the xlms file
sheet_name="Final Exam Perfomance"
df=pd.read_excel("C:\\Users\\TECHSKILLS 360\\Downloads\\Ujuzi Data Summary.xlsx","Final Exam Perfomance",engine='openpyxl')

#how many rows are null
df.isnull().sum()
# Out:
#                                     2873
# No                                     1
# STUDENTS_NAME                          0
# UFA Reg No                             0
# Time taken                           729
# Final Theory                         108
# Practical(A) out of 80               312
# Oral Exam out of 20                  149
# Final Practical                      109
# Final Icare (Theory + Practical)    1295
# Hospital Internship Score            122
# Final Score                          125
# Final Grade                           94
# ID Numbers                           107
# Hospital Internship Attended - 2      36
# Start Date of Class                    6
# End Date of Class                      3
# Class ID                            1873
# Year                                   2
# Branch                                 0
# Course                                 0
# Month Of Class                         3
# Type of Class                         25
# ...

# %%
import pandas as pd

#reading a xlms file
df=pd.read_excel("C:\\Users\\TECHSKILLS 360\\Downloads\\Ujuzi Data Summary.xlsx")

#read a specific file from the xlms file
sheet_name="Final Exam Perfomance"
df=pd.read_excel("C:\\Users\\TECHSKILLS 360\\Downloads\\Ujuzi Data Summary.xlsx","Final Exam Perfomance",engine='openpyxl')

# Specify row indices to drop
rows_to_drop = [2498, 2739, 2750, 2878, 2879, 2880, 2881, 2882] 

#checking if rows have been dropped
print("Original DataFrame:")
print(df)
print("DataFrame after dropping rows:")
print()
# Out:
# Original DataFrame:
#                No             STUDENTS_NAME UFA Reg No       Time taken  \
# 0     NaN     1.0             Jacinta Onono        449              NaN
# 1     NaN     2.0              Grace Njenga        451              NaN
# 2     NaN     3.0           Esther Nasimiyu        452              NaN
# 3     NaN     4.0             Hannah Karuga        453              NaN
# 4     NaN     5.0             Nancy Gitonga        454              NaN
# ...   ...     ...                       ...        ...              ...
# 2870  NaN  2873.0  Joseph Kiprotich Chelule     24-401   55 mins 9 secs
# 2871  NaN  2874.0     Kulthum Abdalla Ahmed     24-303  59 mins 12 secs
# 2872  NaN  2875.0     Mary Wanjiku Gathecha     24-379     1 hour 1 min
# 2873  NaN  2876.0            Steffy Dorothy     24-387  51 mins 59 secs
# 2874  NaN  2877.0     Khadija Tausir Athman     24-378  55 mins 20 secs
#
#       Final Theory Practical(A) out of 80 Oral Exam out of 20 Final Practical  \
# ...

# %%
#how many rows are null
df.isnull().sum()
# Out:
#                                     2873
# No                                     1
# STUDENTS_NAME                          0
# UFA Reg No                             0
# Time taken                           729
# Final Theory                         108
# Practical(A) out of 80               312
# Oral Exam out of 20                  149
# Final Practical                      109
# Final Icare (Theory + Practical)    1295
# Hospital Internship Score            122
# Final Score                          125
# Final Grade                           94
# ID Numbers                           107
# Hospital Internship Attended - 2      36
# Start Date of Class                    6
# End Date of Class                      3
# Class ID                            1873
# Year                                   2
# Branch                                 0
# Course                                 0
# Month Of Class                         3
# Type of Class                         25
# ...

# %%
import pandas as pd

#reading a xlms file
df=pd.read_excel("C:\\Users\\TECHSKILLS 360\\Downloads\\Ujuzi Data Summary.xlsx")

#read a specific file from the xlms file
sheet_name="Final Exam Perfomance"
df=pd.read_excel("C:\\Users\\TECHSKILLS 360\\Downloads\\Ujuzi Data Summary.xlsx","Final Exam Perfomance",engine='openpyxl')

#how many rows are null
df.isnull().sum()
# Out:
#                                     2873
# No                                     1
# STUDENTS_NAME                          0
# UFA Reg No                             0
# Time taken                           729
# Final Theory                         108
# Practical(A) out of 80               312
# Oral Exam out of 20                  149
# Final Practical                      109
# Final Icare (Theory + Practical)    1295
# Hospital Internship Score            122
# Final Score                          125
# Final Grade                           94
# ID Numbers                           107
# Hospital Internship Attended - 2      36
# Start Date of Class                    6
# End Date of Class                      3
# Class ID                            1873
# Year                                   2
# Branch                                 0
# Course                                 0
# Month Of Class                         3
# Type of Class                         25
# ...

# %%
# List of columns where you want to replace empty rows with "Null"
columns_to_replace = [' ', 'No','STUDENTS_NAME', 'UFA Reg No', 'Time taken', 'Final Theory',
       'Practical(A) out of 80', 'Oral Exam out of 20', 'Final Practical',
       'Final Icare (Theory + Practical)', 'Hospital Internship Score',
       'Final Score', 'Final Grade', 'ID Numbers',
       'Hospital Internship Attended - 2', 'Start Date of Class',
       'End Date of Class', 'Class ID', 'Year', 'Branch', 'Course',
       'Month Of Class', 'Type of Class', 'Status',
       'School Internship attended', 'School Internship score']
      # Replace with your column names
# Replace NaN or empty values in the specified columns with "Null"
df[columns_to_replace] = df[columns_to_replace].fillna("Null")
# Display the updated DataFrame to ensure the empty rows have been replaced
print(df)
# Out:
#                 No             STUDENTS_NAME UFA Reg No       Time taken  \
# 0     Null     1.0             Jacinta Onono        449             Null
# 1     Null     2.0              Grace Njenga        451             Null
# 2     Null     3.0           Esther Nasimiyu        452             Null
# 3     Null     4.0             Hannah Karuga        453             Null
# 4     Null     5.0             Nancy Gitonga        454             Null
# ...    ...     ...                       ...        ...              ...
# 2870  Null  2873.0  Joseph Kiprotich Chelule     24-401   55 mins 9 secs
# 2871  Null  2874.0     Kulthum Abdalla Ahmed     24-303  59 mins 12 secs
# 2872  Null  2875.0     Mary Wanjiku Gathecha     24-379     1 hour 1 min
# 2873  Null  2876.0            Steffy Dorothy     24-387  51 mins 59 secs
# 2874  Null  2877.0     Khadija Tausir Athman     24-378  55 mins 20 secs
#
#      Final Theory Practical(A) out of 80 Oral Exam out of 20 Final Practical  \
# ...

# %%
print(df.columns)
# Out:
# Index([' ', 'No', 'STUDENTS_NAME', 'UFA Reg No', 'Time taken', 'Final Theory',
#        'Practical(A) out of 80', 'Oral Exam out of 20', 'Final Practical',
#        'Final Icare (Theory + Practical)', 'Hospital Internship Score',
#        'Final Score', 'Final Grade', 'ID Numbers',
#        'Hospital Internship Attended - 2', 'Start Date of Class',
#        'End Date of Class', 'Class ID', 'Year', 'Branch', 'Course',
#        'Month Of Class', 'Type of Class', 'Status',
#        'School Internship attended', 'School Internship score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
#                                     0
# No                                  0
# STUDENTS_NAME                       0
# UFA Reg No                          0
# Time taken                          0
# Final Theory                        0
# Practical(A) out of 80              0
# Oral Exam out of 20                 0
# Final Practical                     0
# Final Icare (Theory + Practical)    0
# Hospital Internship Score           0
# Final Score                         0
# Final Grade                         0
# ID Numbers                          0
# Hospital Internship Attended - 2    0
# Start Date of Class                 0
# End Date of Class                   0
# Class ID                            0
# Year                                0
# Branch                              0
# Course                              0
# Month Of Class                      0
# Type of Class                       0
# Status                              0
# School Internship attended          0
# ...

# %%
df=pd.read_csv("D_Ujuzi.csv")
